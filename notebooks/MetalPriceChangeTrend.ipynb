# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/raw/MetalPriceChange.csv')

# %%
data = data.dropna(how="all")

# %%
data
# Out:
#      Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  \
# 0    1992   Feb     1266.83      353.91       7861.90          4.15
# 1    1992   Mar     1280.47      344.34       7417.70          4.11
# 2    1992   Apr     1317.05      338.62       7420.60          4.05
# 3    1992   May     1306.79      337.24       7326.80          4.07
# 4    1992   Jun     1275.55      340.81       7192.80          4.06
# ..    ...   ...         ...         ...           ...           ...
# 355  2021   Sep     2834.56     1775.14      19376.88         23.19
# 356  2021   Oct     2934.39     1776.85      19362.39         23.41
# 357  2021   Nov     2636.45     1821.76      19932.86         24.18
# 358  2021   Dec     2695.53     1790.43      20015.55         22.53
# 359  2022   Jan     3005.98     1816.02      22355.40         23.16
#
#      Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# 0          7.90           89.59      2401.782997       670.977969
# ...

# %%
data.shape
# Out:
# (360, 13)

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Price_alum', 'Price_gold', 'Price_nickel',
#        'Price_silver', 'Price_uran', 'Inflation_rate', 'Price_alum_infl',
#        'Price_gold_infl', 'Price_nickel_infl', 'Price_silver_infl',
#        'Price_uran_infl'],
#       dtype='object')

# %%
data.isnull()
# Out:
#       Year  Month  Price_alum  Price_gold  Price_nickel  Price_silver  \
# 0    False  False       False       False         False         False
# 1    False  False       False       False         False         False
# 2    False  False       False       False         False         False
# 3    False  False       False       False         False         False
# 4    False  False       False       False         False         False
# ..     ...    ...         ...         ...           ...           ...
# 355  False  False       False       False         False         False
# 356  False  False       False       False         False         False
# 357  False  False       False       False         False         False
# 358  False  False       False       False         False         False
# 359  False  False       False       False         False         False
#
#      Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# ...

# %%
data.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Price_alum            0
# Price_gold            0
# Price_nickel          0
# Price_silver          0
# Price_uran            2
# Inflation_rate       13
# Price_alum_infl       1
# Price_gold_infl       1
# Price_nickel_infl     1
# Price_silver_infl     1
# Price_uran_infl       1
# dtype: int64

# %%
data['Price_uran'] = data['Price_uran'].interpolate()
data['Price_uran'] = data['Price_uran'].ffill()

# %%
data.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Price_alum            0
# Price_gold            0
# Price_nickel          0
# Price_silver          0
# Price_uran            0
# Inflation_rate       13
# Price_alum_infl       1
# Price_gold_infl       1
# Price_nickel_infl     1
# Price_silver_infl     1
# Price_uran_infl       1
# dtype: int64

# %%
data['Inflation_rate'] = data['Inflation_rate'].interpolate()
data['Inflation_rate'] = data['Inflation_rate'].ffill()
data['Price_alum_infl'] = data['Price_alum_infl'].interpolate()
data['Price_alum_infl'] = data['Price_alum_infl'].ffill()
data['Price_gold_infl'] = data['Price_gold_infl'].interpolate()
data['Price_gold_infl'] = data['Price_gold_infl'].ffill()
data['Price_uran_infl'] = data['Price_uran_infl'].interpolate()
data['Price_uran_infl'] = data['Price_uran_infl'].ffill()
data['Price_silver_infl'] = data['Price_silver_infl'].interpolate()
data['Price_silver_infl'] = data['Price_silver_infl'].ffill()
data['Price_nickel_infl'] = data['Price_nickel_infl'].interpolate()
data['Price_nickel_infl'] = data['Price_nickel_infl'].ffill()

# %%
data.isnull().sum()
# Out:
# Year                 0
# Month                0
# Price_alum           0
# Price_gold           0
# Price_nickel         0
# Price_silver         0
# Price_uran           0
# Inflation_rate       0
# Price_alum_infl      0
# Price_gold_infl      0
# Price_nickel_infl    0
# Price_silver_infl    0
# Price_uran_infl      0
# dtype: int64

# %%
data
# Out:
#      Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  \
# 0    1992   Feb     1266.83      353.91       7861.90          4.15
# 1    1992   Mar     1280.47      344.34       7417.70          4.11
# 2    1992   Apr     1317.05      338.62       7420.60          4.05
# 3    1992   May     1306.79      337.24       7326.80          4.07
# 4    1992   Jun     1275.55      340.81       7192.80          4.06
# ..    ...   ...         ...         ...           ...           ...
# 355  2021   Sep     2834.56     1775.14      19376.88         23.19
# 356  2021   Oct     2934.39     1776.85      19362.39         23.41
# 357  2021   Nov     2636.45     1821.76      19932.86         24.18
# 358  2021   Dec     2695.53     1790.43      20015.55         22.53
# 359  2022   Jan     3005.98     1816.02      22355.40         23.16
#
#      Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# 0          7.90           89.59      2401.782997       670.977969
# ...

# %%
data.head()
# Out:
#    Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  Price_uran  \
# 0  1992   Feb     1266.83      353.91        7861.9          4.15        7.90
# 1  1992   Mar     1280.47      344.34        7417.7          4.11        7.75
# 2  1992   Apr     1317.05      338.62        7420.6          4.05        7.75
# 3  1992   May     1306.79      337.24        7326.8          4.07        7.55
# 4  1992   Jun     1275.55      340.81        7192.8          4.06        7.75
#
#    Inflation_rate  Price_alum_infl  Price_gold_infl  Price_nickel_infl  \
# 0           89.59      2401.782997       670.977969        14905.37621
# 1           89.59      2427.643073       652.834206        14063.21743
# 2           89.59      2496.995095       641.989658        14068.71554
# 3           89.59      2477.543161       639.373316        13890.88012
# 4           89.59      2418.315245       646.141679        13636.82952
#
#    Price_silver_infl  Price_uran_infl
# ...

# %%
data.tail()
# Out:
#      Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  \
# 355  2021   Sep     2834.56     1775.14      19376.88         23.19
# 356  2021   Oct     2934.39     1776.85      19362.39         23.41
# 357  2021   Nov     2636.45     1821.76      19932.86         24.18
# 358  2021   Dec     2695.53     1790.43      20015.55         22.53
# 359  2022   Jan     3005.98     1816.02      22355.40         23.16
#
#      Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# 355       45.08           -1.29      2797.994176      1752.240694
# 356       38.48           -1.29      2896.536369      1753.928635
# 357       31.10           -1.29      2602.439795      1798.259296
# 358       31.10           -1.29      2660.757663      1767.333453
# 359       31.10           -1.29      2660.757663      1767.333453
#
#      Price_nickel_infl  Price_silver_infl  Price_uran_infl
# 355        19126.91825          22.890849        44.498468
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               360 non-null    int64
#  1   Month              360 non-null    object
#  2   Price_alum         360 non-null    float64
#  3   Price_gold         360 non-null    float64
#  4   Price_nickel       360 non-null    float64
#  5   Price_silver       360 non-null    float64
#  6   Price_uran         360 non-null    float64
#  7   Inflation_rate     360 non-null    float64
#  8   Price_alum_infl    360 non-null    float64
#  9   Price_gold_infl    360 non-null    float64
#  10  Price_nickel_infl  360 non-null    float64
#  11  Price_silver_infl  360 non-null    float64
#  12  Price_uran_infl    360 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
data.describe()
# Out:
#               Year   Price_alum   Price_gold  Price_nickel  Price_silver  \
# count   360.000000   360.000000   360.000000    360.000000    360.000000
# mean   2006.583333  1803.781972   838.257944  13176.930750     12.852333
# std       8.671906   442.612174   527.338820   7682.024357      8.716378
# min    1992.000000  1039.810000   256.080000   3871.930000      3.650000
# 25%    1999.000000  1466.685000   355.237500   7320.405000      5.077500
# 50%    2007.000000  1738.535000   655.280000  11663.550000     12.350000
# 75%    2014.000000  2042.630000  1282.185000  16749.457500     17.585000
# max    2022.000000  3071.240000  1968.630000  52179.050000     42.700000
#
#        Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# count  360.000000      360.000000       360.000000       360.000000
# mean    28.409500       36.009222      2359.105888      1014.142923
# std     21.326892       26.665141       449.827203       505.723862
# ...

# %%
data.shape
# Out:
# (360, 13)

# %%
data["Year"].isnull().sum()
# Out:
# np.int64(0)

# %%
data = data.dropna(subset=["Year"])

# %%
data["Year"] = data["Year"].astype(int)

# %%
data.head()
# Out:
#    Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  Price_uran  \
# 0  1992   Feb     1266.83      353.91        7861.9          4.15        7.90
# 1  1992   Mar     1280.47      344.34        7417.7          4.11        7.75
# 2  1992   Apr     1317.05      338.62        7420.6          4.05        7.75
# 3  1992   May     1306.79      337.24        7326.8          4.07        7.55
# 4  1992   Jun     1275.55      340.81        7192.8          4.06        7.75
#
#    Inflation_rate  Price_alum_infl  Price_gold_infl  Price_nickel_infl  \
# 0           89.59      2401.782997       670.977969        14905.37621
# 1           89.59      2427.643073       652.834206        14063.21743
# 2           89.59      2496.995095       641.989658        14068.71554
# 3           89.59      2477.543161       639.373316        13890.88012
# 4           89.59      2418.315245       646.141679        13636.82952
#
#    Price_silver_infl  Price_uran_infl
# ...

# %%
data.iloc[1]
# Out:
# Year                        1992
# Month                        Mar
# Price_alum               1280.47
# Price_gold                344.34
# Price_nickel              7417.7
# Price_silver                4.11
# Price_uran                  7.75
# Inflation_rate             89.59
# Price_alum_infl      2427.643073
# Price_gold_infl       652.834206
# Price_nickel_infl    14063.21743
# Price_silver_infl       7.792149
# Price_uran_infl        14.693225
# Name: 1, dtype: object

# %%
data["Date"] = pd.to_datetime(
    data["Year"].astype(str) + "-" + data["Month"],
    errors="coerce"
)
# Out:
# C:\Users\LIANNAKA DADI\AppData\Local\Temp\ipykernel_20800\1583149261.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Date"] = pd.to_datetime(

# %%
data.set_index("Date", inplace=True)

# %%
data.head()
# Out:
#             Year Month  Price_alum  Price_gold  Price_nickel  Price_silver  \
# Date
# 1992-02-01  1992   Feb     1266.83      353.91        7861.9          4.15
# 1992-03-01  1992   Mar     1280.47      344.34        7417.7          4.11
# 1992-04-01  1992   Apr     1317.05      338.62        7420.6          4.05
# 1992-05-01  1992   May     1306.79      337.24        7326.8          4.07
# 1992-06-01  1992   Jun     1275.55      340.81        7192.8          4.06
#
#             Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# Date
# 1992-02-01        7.90           89.59      2401.782997       670.977969
# 1992-03-01        7.75           89.59      2427.643073       652.834206
# 1992-04-01        7.75           89.59      2496.995095       641.989658
# 1992-05-01        7.55           89.59      2477.543161       639.373316
# 1992-06-01        7.75           89.59      2418.315245       646.141679
#
# ...

# %%
df=data[['Price_alum','Price_gold','Price_nickel','Price_silver','Price_uran']]
df
# Out:
#             Price_alum  Price_gold  Price_nickel  Price_silver  Price_uran
# Date
# 1992-02-01     1266.83      353.91       7861.90          4.15        7.90
# 1992-03-01     1280.47      344.34       7417.70          4.11        7.75
# 1992-04-01     1317.05      338.62       7420.60          4.05        7.75
# 1992-05-01     1306.79      337.24       7326.80          4.07        7.55
# 1992-06-01     1275.55      340.81       7192.80          4.06        7.75
# ...                ...         ...           ...           ...         ...
# 2021-09-01     2834.56     1775.14      19376.88         23.19       45.08
# 2021-10-01     2934.39     1776.85      19362.39         23.41       38.48
# 2021-11-01     2636.45     1821.76      19932.86         24.18       31.10
# 2021-12-01     2695.53     1790.43      20015.55         22.53       31.10
# 2022-01-01     3005.98     1816.02      22355.40         23.16       31.10
#
# [360 rows x 5 columns]

# %%
(data["Price_gold"] > 1500).value_counts()
# Out:
# Price_gold
# False    310
# True      50
# Name: count, dtype: int64

# %%
df.index
# Out:
# DatetimeIndex(['1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#                '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01',
#                '1992-10-01', '1992-11-01',
#                ...
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
#                '2021-12-01', '2022-01-01'],
#               dtype='datetime64[ns]', name='Date', length=360, freq=None)

# %%
df.values
# Out:
# array([[1.266830e+03, 3.539100e+02, 7.861900e+03, 4.150000e+00,
#         7.900000e+00],
#        [1.280470e+03, 3.443400e+02, 7.417700e+03, 4.110000e+00,
#         7.750000e+00],
#        [1.317050e+03, 3.386200e+02, 7.420600e+03, 4.050000e+00,
#         7.750000e+00],
#        ...,
#        [2.636450e+03, 1.821760e+03, 1.993286e+04, 2.418000e+01,
#         3.110000e+01],
#        [2.695530e+03, 1.790430e+03, 2.001555e+04, 2.253000e+01,
#         3.110000e+01],
#        [3.005980e+03, 1.816020e+03, 2.235540e+04, 2.316000e+01,
#         3.110000e+01]], shape=(360, 5))

# %%
data[['Price_alum','Price_gold','Price_nickel','Price_silver','Price_uran']].plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(10,5))
plt.plot(data.index, data["Price_gold"])
plt.title("Gold Price Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Gold Price")
plt.show()

# %%
data['Price_silver'].plot(kind="box", title="Metal Price Volatility")
# Out:
# <Axes: title={'center': 'Metal Price Volatility'}>

# %%
price_cols = ["Price_alum", "Price_gold","Price_silver"]

# %%
data[price_cols].mean().plot(kind="bar", title="Average Metal Prices")
# Out:
# <Axes: title={'center': 'Average Metal Prices'}>

# %%
print("Highest Gold Price:", data["Price_gold"].max())
print("Lowest Gold Price:", data["Price_gold"].min())
# Out:
# Highest Gold Price: 1968.63
# Lowest Gold Price: 256.08

# %%
type(data['Price_silver'].value_counts())
# Out:
# pandas.core.series.Series

# %%
data[["Price_gold", "Price_gold_infl"]].plot(kind="line",title="Gold Price: Actual vs Inflation Adjusted")
# Out:
# <Axes: title={'center': 'Gold Price: Actual vs Inflation Adjusted'}, xlabel='Date'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(14,10))

# Aluminium
data[["Price_alum", "Price_alum_infl"]].plot(ax=axes[0,0], title="Aluminium")

# Gold
data[["Price_gold", "Price_gold_infl"]].plot(ax=axes[0,1], title="Gold")

# Silver
data[["Price_silver", "Price_silver_infl"]].plot(ax=axes[1,0], title="Silver")

# Uranium
data[["Price_uran", "Price_uran_infl"]].plot(ax=axes[1,1], title="Uranium")

plt.tight_layout()
plt.show()

# %%
print(data.index)
# Out:
# DatetimeIndex(['1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#                '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01',
#                '1992-10-01', '1992-11-01',
#                ...
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
#                '2021-12-01', '2022-01-01'],
#               dtype='datetime64[ns]', name='Date', length=360, freq=None)

# %%
print(data.columns)
# Out:
# Index(['Year', 'Month', 'Price_alum', 'Price_gold', 'Price_nickel',
#        'Price_silver', 'Price_uran', 'Inflation_rate', 'Price_alum_infl',
#        'Price_gold_infl', 'Price_nickel_infl', 'Price_silver_infl',
#        'Price_uran_infl'],
#       dtype='object')

# %%
data.reset_index(inplace=True)

# %%
data.to_csv("../data/processed/cleaned_metal_prices.csv", index=False)
